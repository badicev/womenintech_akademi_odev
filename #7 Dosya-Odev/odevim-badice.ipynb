# %%
def metin_temizle(filename):
#Dosyayı oku.
    import re
    file = open(filename, 'rt', encoding='utf-8')
    text = file.read()
    file.close()

    
    text = text.lower()
     #Türkçe karakterleri ve internet sayfasında satır atlamalarını kaldırmak için
    turkce_yabancı_sozluk = {'ç': 'c', 'ğ': 'g', 'ı': 'i', 'ö': 'o', 'ş': 's',
    'ü': 'u', "▼": "", "\n": ""}

    for key, value in turkce_yabancı_sozluk.items():
        text = text.replace(key, value)

    
   
    #regex ile 3 ile daha fazla sayıdan oluşan kelimeleri kaldır. Yabancı karakterleri kaldır. Boşlukları kaldır.
    patterns = ('/(\S)\1(\1)+/g',  '/\d{3,}/g') #r'[\n\r]') 
    for pattern in patterns:
        text = re.sub(pattern, '', text)
     #   text = re.sub(r'[^\w\s]','',text)        
    
    
    #Harfleri küçült.
    text = [word.lower() for word in text.split()] 

    
            
    

    #Noktalama işaretlerini kaldır.
    table = str.maketrans('', '', ("!#$%&'()*+,-/:;.<=>?@[\]^_`{|}~")) 
    text = [w.translate(table) for w in text]

    
   
    #sayilar_listesi = re.findall(r'\d+', text) ???

        #Temizlenmiş dosyayı yazdır.
        #ÖNEMLİ NOT: x kullandın, kodu yeniden çalıştırmadan önce oluşan dosyayı kapatman gerekiyor.
    with open("temiz_metin.txt", "x", encoding = "utf-8") as f:
        for word in text:
            f.write(word + " ")


    

    
        #Sayıları yeni bir klasöre aktarmak için:
    with open("sayilar.txt", "x", encoding = "utf-8") as f:
        for word in text:
            res = re.findall(r'(\w+?)(\d+)', word)
            if res:
                with open('sayilar.txt', 'a', encoding = "utf-8") as f:
                    for i in res:
                        f.write(i[1] + "\n ")

    
      


                        
            
                

 
  


    #Kelime sayısını takip etmek için:
    word_count = {}

    for word in text:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1

   
    #En sık kullanılan 10 kelimeyi bulmak için: 
    sorted_word_count = sorted(word_count.items(), key=lambda x: x[1], reverse=True)    
    print(sorted_word_count[:10])
    return word_count

  

     


metin_temizle('all_data.txt')
# Out:
# [('ve', 143222), ('', 50220), ('belediyesi', 31433), ('bir', 29148), ('ile', 23139), ('icin', 22068), ('bu', 18200), ('da', 16554), ('belediye', 16490), ('dr', 15246)]
# {'anasayfaevergi': 1,
#  'odeme0216': 109,
#  '382': 191,
#  '3': 2912,
#  '382baskankurumsalhi̇zmetleri̇mi̇zetki̇nli̇kleradalarhaberleri̇leti̇si̇mebeledi̇yeduyurular05': 1,
#  'ekim': 1317,
#  '2021': 1070,
#  '': 50220,
#  'uluslararasi': 910,
#  'nazim': 398,
#  'hikmet': 512,
#  'siir': 407,
#  'gunleri': 493,
#  'festivali': 523,
#  'basliyor01': 8,
#  'i̇ski̇': 72,
#  'su': 1946,
#  'kesi̇nti̇si̇adalar': 1,
#  'beledi̇yesi̇madem': 1,
#  'ki': 1069,
#  'insani': 261,
#  'bicimlendiren': 1,
#  'yasadigi': 278,
#  'kosullar': 20,
#  'kosullarinizi': 1,
#  'en': 12539,
#  'iyi': 1325,
#  'noktaya': 133,
#  'getirmek': 173,
#  'icin': 22068,
#  'calisiyoruzayrintilarprojeleri̇mi̇zdevam': 1,
#  'eden': 3199,
#  'projeleryesi̇l': 2,
#  'adalar': 237,
#  'i̇ci̇n': 1014,
#  'ci̇cek': 71,
#  've': 143222,
#  'bi̇tki̇': 9,
#  'cenneti̇mi̇ze': 5,
#  'si̇zleri̇': 16,
#  'bekli̇yoruzdevam': 1,
#  'projelerburgazada': 2,
#  'egi̇ti̇m': 1535,
#  'kultur': 8272,
#  'sanat': 9913,
#  'gonulluler': 69,
#  'evi̇': 68,
#  'yaninizdayizdevam': 1,
#  'projelercopumuzu': 2,
#  'cope': 46,
#  'atiyoruz': 18,
#  'adamiza': 4,
#  'sahi̇p': 35,
#  'cikiyoruzdevam': 1,
#  'projelerbi̇r': 2,
#  'yardim': 2275,
#  'eli̇': 11,
#  'de': 9949,
#  'si̇z': 487,
#  'uzatinetki̇nli̇klerumut': 1,
#  'kosalimayrintilartum': 1,
#  'etki̇nli̇kleruluslararasi': 1,
#  'basliyori̇ski̇': 1,
#  'kesi̇nti̇si̇burgazada': 1,
#  'kadastro': 72,
#  'bi̇lgi̇lendi̇rme': 36,
#  'i̇lanimahalle': 1,
#  'afet': 635,
#  'gonullusu': 86,
#  'olmak': 2975,
#  'isteyen': 565,
#  'adalilara': 5,
#  'cagriheybeli̇ada': 1,
#  'saki̇nleri̇ne': 10,
#  'duyurulurtum': 1,
#  'duyurularbeledi̇ye': 1,
#  'baskanierdem': 1,
#  'gulbaskanin': 1,
#  'ozgecmi̇si̇baskanin': 27,
#  'mesajihaberlertum': 1,
#  'haberler06': 9,
#  '202106baskan': 1,
#  'yardimcimiz': 25,
#  'engin': 130,
#  'celik': 255,
#  'akulu': 68,
#  'araclarla': 54,
#  'i̇lgili': 345,
#  'aciklamalarda': 70,
#  'bulundu04': 10,
#  '202104eki̇m': 1,
#  'ayi': 4057,
#  'mecli̇s': 2489,
#  'toplantisinin': 308,
#  'bi̇ri̇nci̇': 41,
#  'bi̇rlesi̇mi̇': 39,
#  'gerceklesti̇baskan': 4,
#  'gul': 184,
#  'amacimiz': 98,
#  'adalilarin': 4,
#  'hayatini': 383,
#  'zorlastirmak': 4,
#  'degi̇l': 38,
#  'kolaylastirmaktir01': 1,
#  '202101dogada': 1,
#  'ogreniyorumvi̇deolari̇stanbul': 1,
#  'tum': 6016,
#  'adalarin': 10,
#  'genel': 1631,
#  'tanitimieylul302016i̇stanbulun': 1,
#  'i̇lk': 1875,
#  'kent': 2429,
#  'muzesi': 212,
#  'olan': 6814,
#  'tanitimieylul': 12,
#  '30': 1003,
#  '2016i̇stanbul': 11,
#  'heybeliada': 23,
#  'burgazada': 13,
#  '2016tum': 1,
#  'vi̇deolargaleri̇burgazadasieadalarei̇mza': 1,
#  'dogrulamai̇hale': 50,
#  'i̇lanlaribi̇lgi̇': 50,
#  'edi̇nmehi̇zmet': 50,
#  'fali̇yet': 68,
#  'raporlarikurumsal': 65,
#  'epostadi̇lekce': 50,
#  'formlarbuyukada': 50,
#  'sanal': 204,
#  'turhayvan': 50,
#  'barinagicikarma': 50,
#  'gemi̇si̇onemli̇': 1,
#  'telefonlarbanka': 1,
#  'hesap': 304,
#  'numaralarimizni̇kah': 1,
#  'akdi̇': 6,
#  'gerekenler©': 1,
#  '2016': 1153,
#  'belediyesiyazilim': 109,
#  'tasarim': 825,
#  'litera': 110,
#  'bilisimebulten': 109,
#  'uyelikselect': 92,
#  'languagebaskan': 2,
#  'tari̇hce': 7,
#  'haberler': 89,
#  'duyurular': 42,
#  'projeler': 391,
#  'cikisanasayfaevergi': 1,
#  '382baskankurumsalhi̇zmetleri̇mi̇zetki̇nli̇kleradalarhaberleri̇leti̇si̇mebeledi̇yeduyurularanasayfa': 108,
#  'baskanbaskanozbaskanin': 3,
#  'ozgecmi̇si̇©': 3,
#  'languageanasayfaevergi': 89,
#  'kurumsalkurumsalorgorgani̇zasyon': 1,
#  'semasimecmecli̇s': 1,
#  'uyeleri̇mecmecli̇s': 1,
#  'gorev': 1502,
#  'yetki̇leri̇mecmecli̇s': 1,
#  'gundemi̇mecmecli̇s': 1,
#  'kararlarikomkomi̇syon': 1,
#  'uyeleri̇komkomi̇syon': 1,
#  'raporlariencencumen': 1,
#  'uyeleri̇encencumen': 1,
#  'yetki̇leri̇encencumen': 1,
#  'kararlaribydbaskan': 1,
#  'yardimcilarimudmudurluklermtdvi̇zyon': 1,
#  'temel': 972,
#  'degerleri̇mi̇zraphi̇zmet': 1,
#  'raporlarietketi̇k': 1,
#  'komi̇syonukshkardes': 1,
#  'sehi̇rlerklgkurumsal': 1,
#  'logo©': 1,
#  'hizmetlerimizhi̇zmetleri̇mi̇zutucret': 1,
#  'tari̇fesi̇prjprojeleri̇mi̇zkntkent': 1,
#  'rehberi̇trhturi̇zm': 1,
#  'rehberi̇kykanun': 1,
#  'yonetmeli̇klervsvapur': 1,
#  'seferleri̇mtmotor': 1,
#  'tari̇fleri̇©': 1,
#  'etkinlikleretki̇nli̇klerocaksubatmartnisanmayishazirantemmuzagustoseylulekimkasimaralik2021': 14,
#  'tumu': 23,
#  'tiyatro': 1697,
#  'sinema': 776,
#  'konser': 600,
#  'opera': 34,
#  'dans': 278,
#  'seminer': 524,
#  'festival': 266,
#  'solen': 60,
#  'turnuva': 101,
#  'etkinlik': 1211,
#  'anma': 586,
#  'etkinligi': 220,
#  '©': 175,
#  'uyelikanasayfaevergi': 17,
#  'adalaradalartartari̇hceyaptari̇hi̇': 3,
#  'yapilarcogcografi̇': 3,
#  'durumunufnufusamzada': 3,
#  'muzeleri̇fotfotograf': 3,
#  'galeri̇vdgvi̇deo': 3,
#  'galeri̇adabuyukadaadaheybeli̇adaadakinaliadaadaburgazadasiadasedef': 3,
#  'adasiadayassiadaadasi̇vri̇adaadakasik': 3,
#  'adasiadatavsan': 3,
#  'adasi©': 3,
#  'haberlerhaberlerhabhaberlerduyduyurulari̇hli̇halelerbasbasinda': 1,
#  'adalaryayyayinlarimiz©': 1,
#  'i̇letisimi̇leti̇si̇milti̇leti̇si̇m': 1,
#  'bi̇lgi̇leri̇mdrmudurluk': 1,
#  'i̇leti̇si̇m': 17,
#  'bi̇lgi̇leri̇befbi̇lgi̇': 1,
#  'edi̇nme': 86,
#  'formufvdform': 1,
#  'dokumanlarkbkan': 1,
#  'bankasiankanketlerssssikca': 1,
#  'sorulan': 59,
#  'sorularhnmhesap': 1,
#  'numaralarimizotlonemli̇': 1,
#  'telefonlarepokurumsal': 1,
#  'e': 567,
#  'postashrsi̇te': 1,
#  'hari̇tasi©': 1,
#  'i̇lanihaberlerduyurulari̇halelerbasinda': 1,
#  'adalaryayinlarimizburgazada': 1,
#  'i̇lanii̇stanbul': 1,
#  'i̇li̇': 4,
#  'i̇lcesi̇ni̇n': 7,
#  'mahallesi̇nde': 6,
#  '3402': 1,
#  'sayili': 6889,
#  'kanununun': 4395,
#  '22’nci̇': 1,
#  'maddesi̇ni̇n': 1,
#  'i̇ki̇nci̇': 204,
#  'fikrasinin': 4,
#  'a': 502,
#  'bendi̇': 1,
#  'yeni̇leme': 325,
#  'calismalari': 1491,
#  '34': 130,
#  '02': 193,
#  'geci̇ci̇': 23,
#  '8': 1363,
#  'maddesi̇': 13,
#  'defa': 238,
#  'calismalarina': 373,
#  'tabi̇': 1,
#  'tutulan': 27,
#  'alanlar': 207,
#  'kapsaminda': 4299,
#  'yapilan': 3229,
#  'calismalar': 857,
#  'tekni̇k': 40,
#  'raporda': 4,
#  'duzeltme': 42,
#  'hari̇tasinin': 3,
#  'ozali̇t': 5,
#  'kopyasinda': 1,
#  'gosteri̇lmi̇sti̇r': 1,
#  'calisma': 1759,
#  'alani': 1020,
#  'sirini': 1,
#  'i̇ceri̇si̇nde': 62,
#  'bulunan': 4119,
#  'tasinmazlarda': 3,
#  'uygulama': 868,
#  'eki̇bi̇nce': 1,
#  'sinirlandirma': 3,
#  'tespi̇tler': 1,
#  'tamamlandigindan': 1,
#  'tespi̇tleri̇n': 1,
#  'aski': 248,
#  'i̇lanina': 1,
#  'alinmadan': 17,
#  'once': 1643,
#  'gercek': 1320,
#  'tuzel': 3915,
#  'ki̇si̇leri̇n': 3,
#  'bi̇lgi̇si̇ne': 1,
#  'sunulmasi': 161,
#  'i̇dari̇': 18,
#  'yoldan': 30,
#  'duzelti̇lmesi̇': 1,
#  'mumkun': 235,
#  'hatalar': 10,
#  'nedeni̇': 1,
#  'i̇le': 1865,
#  'yapilacak': 1028,
#  'i̇ti̇razlarin': 1,
#  'komi̇syonunda': 5,
#  'i̇ncelenerek': 2,
#  'hak': 729,
#  'kayiplarinin': 4,
#  'onlenmesi̇': 1,
#  'amaciyla': 1715,
#  'duzenlenen': 4327,
#  'li̇steleri̇': 1,
#  'pafta': 530,
#  'ornekleri̇': 1,
#  'bi̇rli̇kte': 63,
#  '15': 1922,
#  'gun': 2794,
#  'sure': 461,
#  'i̇lan': 317,
#  'edi̇lmi̇sti̇rbu': 1,
#  'li̇steler': 1,
#  'tasinmaz': 213,
#  'mallarin': 104,
#  'konumlarinu': 1,
#  'gosteri̇r': 1,
#  'kopyalarinin': 2,
#  'li̇stelerde': 1,
#  'yazili': 446,
#  'mallar': 12,
#  'uzeri̇nde': 4,
#  'tespi̇tlere': 1,
#  'karsi': 1114,
#  'i̇ti̇razi': 1,
#  'olanlarin': 538,
#  'muddeti̇': 1,
#  '02092021': 9,
#  'i̇la': 1,
#  '16092021': 1,
#  'tari̇hleri̇': 22,
#  'arasinda': 2379,
#  'i̇stanbul': 4151,
#  'kartal': 221,
#  'bi̇ri̇mi̇ne': 2,
#  'veya': 7865,
#  'eki̇bi̇ne': 1,
#  'i̇ti̇raz': 3,
#  'etmeleri̇': 2,
#  'sonuclarinin': 38,
#  'gunluk': 366,
#  'cetvelleri̇nde': 1,
#  'gosteri̇lecegi̇': 1,
#  'dava': 62,
#  'acmak': 65,
#  'sureti̇yle': 2,
#  'etmek': 834,
#  'i̇steyenleri̇n': 1,
#  'i̇se': 319,
#  'daha': 5180,
#  'sonra': 2757,
#  'i̇lani': 109,
#  'suresi̇': 29,
#  'yetki̇li̇': 2,
#  'mahkemesi̇nde': 1,
#  'acabi̇lecegi̇tkgmkadastro': 1,
#  'dai̇re': 91,
#  'baskanliginin': 55,
#  '14012013': 1,
#  'tari̇h': 191,
#  '20134': 1,
#  'genelgesi̇': 2,
#  'uyarinca': 3134,
#  'duyurulur': 50,
#  'cetveli': 8,
#  'orneklerini': 34,
#  'belediye': 16490,
#  'binasi': 461,
#  'panosu': 20,
#  'burgazadasi': 5,
#  'muhtarligindan': 2,
#  'i̇nceleyebilirsinizson': 1,
#  'duyurular05': 6,
#  '2021uluslararasi': 8,
#  '2021i̇ski̇': 7,
#  'kesi̇nti̇si̇02': 7,
#  'eylul': 1724,
#  '2021burgazada': 7,
#  'i̇lanibeledi̇ye': 7,
#  'baskanibaskanin': 28,
#  'mesajieadalarei̇mza': 25,
#  'gemi̇si̇©': 49,
#  'mahalle': 1488,
#  'cagrihaberlerduyurulari̇halelerbasinda': 1,
#  'adalaryayinlarimizmahalle': 1,
#  'cagriherhangi': 1,
#  'bir': 29148,
#  'durumunda': 251,
#  'depremyangin': 1,
#  'vb': 391,
#  'adada': 28,
#  'yasayanlarin': 30,
#  'adalardaki': 3,
#  'degisken': 7,
#  'nufusun': 19,
#  'can': 432,
#  'guvenligini': 53,
#  'saglamak': 864,
#  'sonrasi': 413,
#  'calismalarda': 146,
#  'almak': 396,
#  'buyukada': 27,
#  'projesi̇': 1104,
#  'programi': 1311,
#  '06': 362,
#  'saat': 2493,
#  '2000’da': 60,
#  'konseyinde': 12,
#  'basliyor': 196,
#  'son': 3504,
#  'mag': 9,
#  'egitim': 6875,
#  'programi05': 1,
#  'heybeli̇ada': 5,
#  'duyurulurhaberlerduyurulari̇halelerbasinda': 2,
#  'adalaryayinlarimizheybeli̇ada': 2,
#  'duyurulurcan': 1,
#  'dostlarimiz': 32,
#  'mobil': 434,
#  'veteriner': 350,
#  'klinigi': 3,
#  'yayinlanmistirson': 1,
#  'sahnehaberlerduyurulari̇halelerbasinda': 1,
#  'adalaryayinlarimizi̇stanbul': 1,
#  'sahnei̇stanbul': 1,
#  'sahnesaat': 1,
#  '1300da': 4,
#  'meydanindason': 1,
#  'ulkemiz': 103,
#  'genelinde': 425,
#  'yasanan': 448,
#  'hepimizi': 21,
#  'derinden': 27,
#  'sarsan': 6,
#  'yangin': 194,
#  'bolgeleri': 39,
#  'oncelikli': 102,
#  'ihtiyac': 1029,
#  'listesihaberlerduyurulari̇halelerbasinda': 1,
#  'adalaryayinlarimizulkemiz': 1,
#  'listesidegerli': 1,
#  'adalilarulkemiz': 1,
#  'listesibuz': 1,
#  'yanik': 12,
#  'merhemi': 1,
#  'gaz': 55,
#  'maskesi': 11,
#  'yanmaz': 3,
#  'kiyafetler': 27,
#  'bot': 27,
#  'cizmeayakkabi': 1,
#  'baret': 3,
#  'tepe': 32,
#  'lambasi': 11,
#  'el': 1178,
#  'feneri': 16,
#  'koruyucu': 129,
#  'gozlugu': 2,
#  'sirt': 14,
#  'tipi': 74,
#  'sulama': 33,
#  'ekipmani': 14,
#  'topu': 47,
#  'hortumu': 2,
#  'feklektif': 1,
#  'yelek': 2,
#  'megafon': 2,
#  'arac': 497,
#  'soguk': 146,
#  'muhafaza': 81,
#  'buz': 241,
#  'kabi': 5,
#  'powerbank': 4,
#  'termostur': 1,
#  'yukarida': 133,
#  'yer': 5810,
#  'alan': 3623,
#  'listedeki': 7,
#  'malzemeler': 121,
#  'kampanyasina': 111,
#  'destek': 10074,
#  'isteyenler': 153,
#  'belediyemize': 218,
#  '216': 347,
#  '33': 95,
#  '82315': 1,
#  'basvurabilirlerev': 1,
#  'esyasi': 28,
#  'yatak': 56,
#  'yorgan': 6,
#  'vs': 112,
#  'kampanyasi': 201,
#  'yanginlar': 7,
#  'tam': 726,
#  'olarak': 12631,
#  'kontrol': 1214,
#  'altina': 299,
#  'alindiktan': 15,
#  'bolgeden': 17,
#  'gelen': 2392,
#  'talepler': 70,
#  'dogrultusunda': 541,
#  'baslatilacaktironcelikli': 1,
#  'listesi': 54,
#  'basvuruda': 48,
#  'bulunmak': 166,
#  'sosyal': 7351,
#  'meydya': 1,
#  'hesaplarimiz': 2,
#  'uzerinden': 2412,
#  'direk': 27,
#  'mesaj': 101,
#  'dm': 1,
#  'basvurabilirlerduyarliliginiza': 1,
#  'tesekkur': 2096,
#  'ederizson': 2,
#  'i̇lcesi': 367,
#  'orman': 162,
#  'yanginlariyla': 5,
#  'mucadele': 1125,
#  'komisyonu': 1093,
#  'kararlarihaberlerduyurulari̇halelerbasinda': 1,
#  'adalaryayinlarimizadalar': 1,
#  'kararlarii̇stanbul': 1,
#  'valiliginin': 4,
#  'almis': 167,
#  'oldugu': 2832,
#  '30072021': 1,
#  'tarih': 3025,
#  '20211': 2,
#  '"orman': 1,
#  'yanginlarinin': 10,
#  'onlenmesi': 53,
#  'ormanlik': 28,
#  'alanlara': 81,
#  'girislerin': 2,
#  'yasaklanmasi': 3,
#  'hakkindaki': 93,
#  'karari"na': 1,
#  'ilave': 96,
#  'kararlari': 111,
#  'geregince': 589,
#  '04082021\xad31082021': 1,
#  'tarihleri': 613,
#  'araliginda1': 1,
#  'duzenli': 351,
#  'tarifeli': 1,
#  'seferler': 6,
#  'disinda': 378,
#  'adalara': 6,
#  'yonelik': 1454,
#  'gunubirlik': 16,
#  'turistik': 38,
#  'gezi': 228,
#  'yapan': 1503,
#  'deniz': 498,
#  'araclarinin': 38,
#  'iskelelere': 1,
#  'yanasmasina': 1,
#  'baglanmasina': 1,
#  '7\xad81415': 1,
#  'cumartesipazar': 4,
#  'agustos': 1005,
#  'pazartesi': 897,
#  'gunu': 3913,
#  'izin': 304,
#  'verilmemesine': 1,
#  'iskele': 23,
#  'amirliklerince': 1,
#  'zabita': 1107,
#  'marifetiyle': 8,
#  'denetlenmesine2': 1,
#  'ilcesinde': 135,
#  'tabiat': 33,
#  'parklari': 93,
#  'mesire': 36,
#  'yerlerinin': 88,
#  'icerisinde': 1374,
#  'bitisiginde': 9,
#  'olmasi': 3593,
#  'nedeniyle': 1048,
#  'alanlarinda': 250,
#  'piknik': 285,
#  'yapilmasinin': 22,
#  'yasaklanmasina': 1,
#  'uyari': 51,
#  'ikaz': 5,
#  'levhalarinin': 3,
#  'konulmasina3': 1,
#  'elektrikli': 146,
#  'toplu': 491,
#  'ulasim': 569,
#  'seferlerinin': 3,
#  'alanlarda': 319,
#  'kontrollu': 37,
#  'durmaksizin': 9,
#  'inme': 3,
#  'binmeye': 1,
#  'verilmeksizin': 1,
#  'yapilmasina4': 1,
#  'plaj': 12,
#  'yerlerine': 72,
#  'ulasimin': 14,
#  'sadece': 1700,
#  'araclari': 337,
#  'ile': 23139,
#  'yapilmasina5': 1,
#  'yerlerinden': 46,
#  'ormana': 4,
#  'cikis': 71,
#  'yollarinin': 19,
#  'cevresinin': 14,
#  'ilgili': 6327,
#  'isletmeler': 22,
#  'teskilatinca': 1,
#  'tedbirler': 154,
#  'alinarak': 201,
#  'altinda': 775,
#  'tutularak': 21,
#  'denetlenmesine6': 1,
#  'i̇skelelerde': 1,
#  'yanginlarina': 14,
#  'sebebiyet': 11,
#  'verecek': 675,
#  'maddelere': 22,
#  'guvenlik': 343,
#  'guclerince': 1,
#  'denetim': 1695,
#  'yapilmasina7': 1,
#  'giris': 160,
#  'yollarinda': 10,
#  'emniyet': 547,
#  'i̇bb': 323,
#  'i̇sletme': 402,
#  'teskilati': 77,
#  'i̇tfaiye': 60,
#  'personeli': 448,
#  'gonullu': 392,
#  'vatandaslar': 1066,
#  'denetleme': 17,
#  'faaliyetlerinin': 67,
#  'yurutulmesine8': 1,
#  'sahil': 207,
#  'komutanligi': 23,
#  'polisi': 25,
#  'tarafindan': 7519,
#  'araclariyla': 49,
#  'cevresinde': 107,
#  'faaliyeti': 37,
#  'yurutulmesine9': 1,
#  'lojistik': 49,
#  'yuk': 25,
#  'tasiyan': 297,
#  'yanici': 7,
#  'parlayici': 6,
#  'risk': 146,
#  'olusturan': 152,
#  'maddeler': 59,
#  'yonunden': 67,
#  'unsurlari': 21,
#  'denetlenmesine10': 1,
#  'denetimlerde': 38,
#  'tespit': 496,
#  'edilen': 2168,
#  'aykiriliklar': 1,
#  'karsisinda': 179,
#  '6831': 2,
#  'kanunu': 351,
#  'turk': 2276,
#  'ceza': 125,
#  '5326': 19,
#  'kabahatler': 26,
#  'adli\xad': 1,
#  'idari': 1154,
#  'islem': 171,
#  'yapilmasi;hukumleri': 1,
#  'uygulanacaktir': 13,
#  'duyurulurheybeliadadaki': 1,
#  '18202527': 1,
#  '10001200': 5,
#  'saatleri': 398,
#  'araliginda': 27,
#  'kliniginde': 2,
#  'hekimlerimiz': 12,
#  'hizmet': 4379,
#  'verecektir': 30,
#  'tari̇hi̇': 55,
#  'yapilar': 85,
#  'yapilartari̇hcecografi̇': 1,
#  'durumnufustari̇hi̇': 21,
#  'yapilarada': 21,
#  'muzeleri̇fotograf': 21,
#  'galeri̇vi̇deo': 72,
#  'galeri̇buyukadaheybeli̇adakinaliadaburgazadasisedef': 21,
#  'adasiyassiadasi̇vri̇adakasik': 21,
#  'adasitavsan': 22,
#  'adasihami̇di̇ye': 1,
#  'cami̇i̇2abdulhamidin': 1,
#  'emriyle': 6,
#  'yaptirilan': 64,
#  '1895': 1,
#  'tarihinde': 653,
#  'ibadete': 80,
#  'acilan': 360,
#  'hamidiye': 15,
#  'camii': 377,
#  'zarif': 13,
#  'estetik': 162,
#  'yapidir': 7,
#  'kesme': 56,
#  'kufeki': 4,
#  'tastan': 9,
#  'yapilmis': 190,
#  'olup': 776,
#  'iki': 1640,
#  'katlidir': 2,
#  'tek': 1362,
#  'serefeli': 4,
#  'tas': 493,
#  'minarenin': 4,
#  'kapisi': 126,
#  'da': 16554,
#  'avluya': 1,
#  'acilirdevamini': 1,
#  'okubuyukada': 3,
#  'vapur': 14,
#  'i̇skelesi̇bu': 1,
#  'bina': 298,
#  'osmanli': 421,
#  'neo': 2,
#  'klasik': 227,
#  'akimin': 2,
#  'buyukadadaki': 2,
#  'temsilcisidir': 3,
#  '1914': 4,
#  'yilinda': 2725,
#  'iskelenin': 1,
#  'mimari': 188,
#  'mihran': 1,
#  'azaryandir': 1,
#  'cinileri': 2,
#  'kutahyali': 1,
#  'mehmed': 94,
#  'emin': 289,
#  'efendi': 183,
#  'yapilmistir': 44,
#  '1999': 70,
#  '2001': 27,
#  'yillarinda': 107,
#  'restorasyon': 42,
#  'uygulanmistirdevamini': 1,
#  'okupanayi̇a': 1,
#  'ki̇li̇sesi̇arabacilar': 1,
#  'meydani': 943,
#  'carsi': 45,
#  'caddesine': 12,
#  'kapilari': 30,
#  'panayia': 1,
#  'meryem': 104,
#  'ana': 564,
#  'kilisesi': 18,
#  'sakinleri': 186,
#  'avlu': 7,
#  'kapisinin': 10,
#  'konumu': 39,
#  'arabacilar': 1,
#  'bilinirdevamini': 1,
#  'okuayi̇os': 2,
#  'demetri̇os': 1,
#  'ki̇li̇sesi̇i̇stanbul': 1,
#  'adalarinin': 5,
#  'metropolitik': 1,
#  'katedrali': 2,
#  'buyukadanin"koruyucu': 1,
#  'azizi"': 1,
#  'ayios': 5,
#  'dimitriosa': 1,
#  'adanan': 3,
#  'kilise': 28,
#  '7': 1312,
#  'mayis': 2019,
#  '1856': 1,
#  'acilmistir': 13,
#  'kiremit': 8,
#  'ortulu': 2,
#  'kagir': 3,
#  'yapinin': 91,
#  'fistiki': 1,
#  'fistikos': 1,
#  'kalfadirdevamini': 1,
#  'ni̇kolaos': 1,
#  'manastiribuyukadanin': 1,
#  'dogu': 116,
#  'sahilinde': 34,
#  'sedefadasinin': 1,
#  'nikolaos': 2,
#  'manastirinin': 2,
#  'bulundugu': 1717,
#  'yore': 33,
#  'bizansin': 2,
#  'karya': 1,
#  'karyes': 1,
#  'yerlesimidirdevamini': 1,
#  'okuhased': 1,
#  'le': 8,
#  'avraam': 3,
#  'si̇nagogubuyukadanin': 1,
#  'ilk': 5069,
#  'sinagogu': 1,
#  'hesed': 2,
#  '2': 3771,
#  'abdulhamid': 125,
#  'doneminde': 376,
#  'adanin': 30,
#  'yahudi': 3,
#  'nufusunun': 27,
#  'tapinma': 1,
#  'gereksinimlerini': 21,
#  'yerine': 880,
#  'insa': 480,
#  'edilmistirdevamini': 3,
#  'okusurp': 1,
#  'astvazazi̇n': 1,
#  'verapohum': 1,
#  'ermeni̇': 1,
#  'ki̇li̇sesi̇surp': 1,
#  'asdvadzadzin': 1,
#  'ermeni': 21,
#  'katolik': 1,
#  'kilisesinin': 3,
#  'kutsama': 1,
#  'acilis': 664,
#  'tarihi': 5335,
#  '1858dir': 1,
#  'ananin': 2,
#  'goge': 7,
#  'yukselisi': 5,
#  'yortusuna': 1,
#  'denk': 194,
#  'getirilmistirdevamini': 1,
#  'rum': 44,
#  'yeti̇mhanesi̇buyukadanin': 1,
#  'guzel': 2226,
#  'yeri': 865,
#  'denilebilecek': 2,
#  '"i̇sa': 1,
#  'tepesi"nde': 1,
#  '1898': 1,
#  'kont': 2,
#  'moris': 1,
#  'bostari': 1,
#  'baskanligindaki': 16,
#  'fransiz': 33,
#  'sirketi': 50,
#  'gayet': 24,
#  'genis': 211,
#  'uzunlugu': 23,
#  '1025': 6,
#  'metre': 269,
#  'genisligi': 6,
#  '2535': 1,
#  'muhtesem': 221,
#  'okuhri̇stos': 1,
#  'manastiri': 9,
#  'i̇sa': 45,
#  'tepesi̇buyukadanin': 1,
#  'yuksek': 660,
#  'ikinci': 815,
#  'tepesinin': 3,
#  'uzerinde': 975,
#  'hristos': 4,
#  'yerinde': 398,
#  'ayni': 1982,
#  'adi': 403,
#  'bizans': 46,
#  'gorusu': 45,
#  'bilimsel': 178,
#  'kanit': 3,
#  'yokluguna': 3,
#  'karsin': 20,
#  'yaygindirdevamini': 1,
#  'okuaya': 1,
#  'yorgi̇': 1,
#  'yucetepei̇stanbul': 1,
#  'buyugu': 16,
#  'belki': 125,
#  'guzeli': 27,
#  'buyukadanin': 1,
#  'tepesinde': 3,
#  'halk': 2893,
#  'aya': 24,
#  'yorgi': 8,
#  'bilinen': 146,
#  'agios': 1,
#  'georgios': 4,
#  'ortodoks': 5,
#  'manastin': 1,
#  'bulunmaktadirdevamini': 4,
#  'okuhukumet': 1,
#  'konagicankaya': 1,
#  'caddesi': 1095,
#  '44': 176,
#  'nolu': 909,
#  'kosktur': 1,
#  'buyuk': 3980,
#  'bahce': 313,
#  'ortasindadir': 1,
#  '1900’lerin': 1,
#  'basinda': 398,
#  'yapildigi': 364,
#  'sanilmaktadir': 1,
#  'mermer': 29,
#  'doseli': 1,
#  'kopru': 82,
#  'girilir': 2,
#  'orta': 486,
#  'sofali': 1,
#  'planlidir': 1,
#  'girise': 2,
#  'gore': 3935,
#  'sol': 45,
#  'taraftaki': 4,
#  'kule': 16,
#  'seyir': 33,
#  'balkonu': 1,
#  'okuanadolu': 1,
#  'kulubui̇stanbul': 3,
#  'nizam': 16,
#  'mahallesinde': 216,
#  'edilmistir': 78,
#  'kesin': 245,
#  'bilinmemektedir': 1,
#  'i̇ngiliz': 29,
#  'yat': 16,
#  'kulubu': 465,
#  'iken': 44,
#  'anadolu': 1228,
#  'devir': 55,
#  'alinmistirdevamini': 1,
#  'okuconk': 1,
#  'pasa': 291,
#  'koskui̇stanbul': 1,
#  'mahallesi': 4029,
#  'cankaya': 7,
#  'caddesi’nde': 139,
#  'kosk': 10,
#  '1880': 1,
#  'midilli': 1,
#  'dogumlu': 76,
#  'con': 4,
#  'yaptirilmistirdevamini': 1,
#  'okugozlu': 1,
#  'evsabuncakis': 1,
#  'kosku': 7,
#  'ilcesi': 149,
#  'maden': 119,
#  'yilmaz': 524,
#  'kiyisindadir': 1,
#  'yapi': 662,
#  'sultan': 654,
#  'ii': 125,
#  'abdulhamit': 42,
#  'doneminin': 67,
#  'meshur': 36,
#  'masonlarindan': 1,
#  'halepli': 13,
#  'sabuncakis': 2,
#  '1904': 1,
#  'okusplendi̇t': 1,
#  'palasdort': 1,
#  'katli': 154,
#  'ahsap': 180,
#  'yapida': 20,
#  'bodrum': 46,
#  'kati': 136,
#  'vardir': 243,
#  'bodrumda': 1,
#  'mutfak': 119,
#  'sicak': 332,
#  'saguk': 1,
#  'kalorifer': 8,
#  'kazanlari': 18,
#  'sogutma': 13,
#  'dolaplari': 7,
#  'kiler': 1,
#  'kuafor': 46,
#  'salonu': 714,
#  'saginda': 1,
#  'yemek': 593,
#  'almaktadir': 420,
#  'oturma': 99,
#  'salonunun': 20,
#  'duvarini': 2,
#  'f': 34,
#  'dubreuil': 1,
#  'duvarlarinidevamini': 1,
#  'okuresat': 1,
#  'nuri̇': 9,
#  'gunteki̇ni̇n': 1,
#  'evi̇unlu': 1,
#  'roman': 71,
#  'yazari': 138,
#  'evi': 781,
#  'evde': 677,
#  'unlu': 455,
#  'romancisi': 6,
#  'resat': 3,
#  'nuri': 82,
#  ...}
